# %% [markdown]
# <hr>
#
# # 🤖 MACHINE LEARNING 🤖
#
# <style>
# h1 {
#     text-align: center;
#     color: hotpink;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <hr>
