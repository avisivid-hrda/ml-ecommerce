# %% [markdown]
# <hr>
#
# # 🧮 STATISTICS 🧮
#
# <style>
# h1 {
#     text-align: center;
#     color: brown;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <hr>
